# %%
import os
import shutil
import pandas as pd

# ✅ Ruta base (solo la carpeta que contiene 'labels.csv' y 'train')
base_path = "data"

# Cargar el CSV correctamente
df = pd.read_csv(os.path.join(base_path, "labels.csv"))

# Filtrar imágenes etiquetadas como "Healthy"
healthy_df = df[df["Condition"] == "Healthy"]

# Crear carpeta destino
output_dir = os.path.join(base_path, "sanos")
os.makedirs(output_dir, exist_ok=True)

# Carpeta de imágenes
train_dir = os.path.join(base_path, "train")

# Contador de imágenes copiadas
copiadas = 0

# Copiar imágenes
for identification in healthy_df["Identification"]:
    file_name = f"{identification}.jpg"
    source_path = os.path.join(train_dir, file_name)
    dest_path = os.path.join(output_dir, file_name)

    if os.path.exists(source_path):
        shutil.copy2(source_path, dest_path)
        copiadas += 1
    else:
        print(f"⚠️ Imagen no encontrada: {file_name}")

print(f"✅ Se copiaron {copiadas} imágenes a la carpeta 'sanos'")
# Out:
# ✅ Se copiaron 1764 imágenes a la carpeta 'sanos'

# %%
import os
import shutil
import pandas as pd

# ✅ Ruta base (solo la carpeta que contiene 'labels.csv' y 'train')
base_path = "data"

# Cargar el CSV correctamente
df = pd.read_csv(os.path.join(base_path, "labels.csv"))

# Filtrar imágenes etiquetadas como "Healthy"
healthy_df = df[df["Condition"] == "Anthracnose"]

# Crear carpeta destino
output_dir = os.path.join(base_path, "Anthracnose-D1")
os.makedirs(output_dir, exist_ok=True)

# Carpeta de imágenes
train_dir = os.path.join(base_path, "train")

# Contador de imágenes copiadas
copiadas = 0

# Copiar imágenes
for identification in healthy_df["Identification"]:
    file_name = f"{identification}.jpg"
    source_path = os.path.join(train_dir, file_name)
    dest_path = os.path.join(output_dir, file_name)

    if os.path.exists(source_path):
        shutil.copy2(source_path, dest_path)
        copiadas += 1
    else:
        print(f"⚠️ Imagen no encontrada: {file_name}")

print(f"✅ Se copiaron {copiadas} imágenes a la carpeta 'sanos'")
# Out:
# ✅ Se copiaron 1022 imágenes a la carpeta 'sanos'

# %%
import os
import shutil
import pandas as pd

# ✅ Ruta base (solo la carpeta que contiene 'labels.csv' y 'train')
base_path = "data"

# Cargar el CSV correctamente
df = pd.read_csv(os.path.join(base_path, "labels.csv"))

# Filtrar imágenes etiquetadas como "Healthy"
healthy_df = df[df["Condition"] == "Scab"]

# Crear carpeta destino
output_dir = os.path.join(base_path, "Scab-D2")
os.makedirs(output_dir, exist_ok=True)

# Carpeta de imágenes
train_dir = os.path.join(base_path, "train")

# Contador de imágenes copiadas
copiadas = 0

# Copiar imágenes
for identification in healthy_df["Identification"]:
    file_name = f"{identification}.jpg"
    source_path = os.path.join(train_dir, file_name)
    dest_path = os.path.join(output_dir, file_name)

    if os.path.exists(source_path):
        shutil.copy2(source_path, dest_path)
        copiadas += 1
    else:
        print(f"⚠️ Imagen no encontrada: {file_name}")

print(f"✅ Se copiaron {copiadas} imágenes a la carpeta 'sanos'")
# Out:
# ✅ Se copiaron 1197 imágenes a la carpeta 'sanos'

# %%
import os
import random
import shutil

# --- CONFIGURACIÓN ---
carpeta_origen = "sanos_con_defectos"   # <- cámbiala por tu ruta real
carpeta_destino = "data/Anthracnose-E1" # <- cámbiala por tu ruta real
cantidad_imagenes = 742  # Número de imágenes que quieres copiar

# Crear la carpeta destino si no existe
os.makedirs(carpeta_destino, exist_ok=True)

# Obtener lista de archivos válidos (solo imágenes)
imagenes = [f for f in os.listdir(carpeta_origen) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Asegurarse que no se pida más de las que hay
cantidad_a_copiar = min(cantidad_imagenes, len(imagenes))

# Seleccionar imágenes al azar
imagenes_aleatorias = random.sample(imagenes, cantidad_a_copiar)

# Copiar las imágenes
for img in imagenes_aleatorias:
    origen = os.path.join(carpeta_origen, img)
    destino = os.path.join(carpeta_destino, img)
    shutil.copy2(origen, destino)
    print(f"✅ Copiada: {img}")

print(f"\n✅ Se copiaron {cantidad_a_copiar} imágenes a '{carpeta_destino}'")
# Out:
# ✅ Copiada: random_def_sano756.png
# ✅ Copiada: random_def_sano269.png
# ✅ Copiada: random_def_sano414.png
# ✅ Copiada: random_def_sano115.png
# ✅ Copiada: random_def_sano761.png
# ✅ Copiada: random_def_sano1497.png
# ✅ Copiada: random_def_sano581.png
# ✅ Copiada: random_def_sano1036.png
# ✅ Copiada: random_def_sano509.png
# ✅ Copiada: random_def_sano390.png
# ✅ Copiada: random_def_sano717.png
# ✅ Copiada: random_def_sano1027.png
# ✅ Copiada: random_def_sano1227.png
# ✅ Copiada: random_def_sano195.png
# ✅ Copiada: random_def_sano442.png
# ✅ Copiada: random_def_sano281.png
# ✅ Copiada: random_def_sano062.png
# ✅ Copiada: random_def_sano023.png
# ✅ Copiada: random_def_sano1117.png
# ✅ Copiada: random_def_sano705.png
# ✅ Copiada: random_def_sano1268.png
# ✅ Copiada: random_def_sano1041.png
# ✅ Copiada: random_def_sano1220.png
# ✅ Copiada: random_def_sano1179.png
# ✅ Copiada: random_def_sano899.png
# ✅ Copiada: random_def_sano1757.png
# ✅ Copiada: random_def_sano1720.png
# ...

# %%
import os
import random
import shutil

# --- CONFIGURACIÓN ---
carpeta_origen = "sanos_con_defectos-scab"   # <- cámbiala por tu ruta real
carpeta_destino = "data/Scab-E2" # <- cámbiala por tu ruta real
cantidad_imagenes = 567  # Número de imágenes que quieres copiar

# Crear la carpeta destino si no existe
os.makedirs(carpeta_destino, exist_ok=True)

# Obtener lista de archivos válidos (solo imágenes)
imagenes = [f for f in os.listdir(carpeta_origen) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Asegurarse que no se pida más de las que hay
cantidad_a_copiar = min(cantidad_imagenes, len(imagenes))

# Seleccionar imágenes al azar
imagenes_aleatorias = random.sample(imagenes, cantidad_a_copiar)

# Copiar las imágenes
for img in imagenes_aleatorias:
    origen = os.path.join(carpeta_origen, img)
    destino = os.path.join(carpeta_destino, img)
    shutil.copy2(origen, destino)
    print(f"✅ Copiada: {img}")

print(f"\n✅ Se copiaron {cantidad_a_copiar} imágenes a '{carpeta_destino}'")
# Out:
# ✅ Copiada: random_def_sano1163.png
# ✅ Copiada: random_def_sano492.png
# ✅ Copiada: random_def_sano1464.png
# ✅ Copiada: random_def_sano459.png
# ✅ Copiada: random_def_sano105.png
# ✅ Copiada: random_def_sano256.png
# ✅ Copiada: random_def_sano397.png
# ✅ Copiada: random_def_sano1065.png
# ✅ Copiada: random_def_sano1652.png
# ✅ Copiada: random_def_sano878.png
# ✅ Copiada: random_def_sano379.png
# ✅ Copiada: random_def_sano609.png
# ✅ Copiada: random_def_sano356.png
# ✅ Copiada: random_def_sano1619.png
# ✅ Copiada: random_def_sano1620.png
# ✅ Copiada: random_def_sano911.png
# ✅ Copiada: random_def_sano1122.png
# ✅ Copiada: random_def_sano229.png
# ✅ Copiada: random_def_sano915.png
# ✅ Copiada: random_def_sano400.png
# ✅ Copiada: random_def_sano703.png
# ✅ Copiada: random_def_sano1067.png
# ✅ Copiada: random_def_sano298.png
# ✅ Copiada: random_def_sano1277.png
# ✅ Copiada: random_def_sano1036.png
# ✅ Copiada: random_def_sano1263.png
# ✅ Copiada: random_def_sano582.png
# ...

# %%
import os
import numpy as np
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import shutil
import cv2
import random

# ---------------------------
# 1. DEFINIR RUTAS
# ---------------------------
dir_defectos = "generated"
dir_sanos = "data/sanos"
dir_resultados = "sanos_con_defectos"
graficos_dir = "graficos_comparacion"

# ---------------------------
# 2. PREPARAR CARPETAS DE SALIDA
# ---------------------------
for folder in [dir_resultados, graficos_dir]:
    shutil.rmtree(folder, ignore_errors=True)
    os.makedirs(folder, exist_ok=True)

# ---------------------------
# 3. FUNCIONES AUXILIARES
# ---------------------------
def detectar_mascara_verde(imagen_rgba):
    imagen_rgb = imagen_rgba.convert("RGB")
    imagen_np = np.array(imagen_rgb)
    hsv = cv2.cvtColor(imagen_np, cv2.COLOR_RGB2HSV)
    lower_green = np.array([30, 40, 40])
    upper_green = np.array([90, 255, 255])
    mask = cv2.inRange(hsv, lower_green, upper_green)
    kernel = np.ones((3, 3), np.uint8)
    return cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=2)

def limpiar_bordes_defecto(defecto_img, umbral=30):
    defecto_img = defecto_img.convert("RGBA")
    defecto_arr = np.array(defecto_img)
    r, g, b = defecto_arr[:, :, 0], defecto_arr[:, :, 1], defecto_arr[:, :, 2]
    mascara_oscura = (r < umbral) & (g < umbral) & (b < umbral)
    defecto_arr[mascara_oscura] = [0, 0, 0, 0]
    return Image.fromarray(defecto_arr)

def create_soft_mask(defect_arr):
    mask = np.any(defect_arr[:, :, :3] != [0, 0, 0], axis=-1).astype(np.uint8) * 255
    mask_img = Image.fromarray(mask, mode="L").filter(ImageFilter.GaussianBlur(radius=1.5))
    return np.array(mask_img).astype(np.float32) / 255.0

def aplicar_defecto_con_mascara_verde(sano_img, defecto_img):
    sano_img = sano_img.convert("RGBA").resize((128, 128))
    defecto_img = limpiar_bordes_defecto(defecto_img, umbral=40).resize((128, 128))
    mask_verde = detectar_mascara_verde(sano_img)
    mask_bin = (mask_verde / 255).astype(np.uint8)
    mask_rgba = np.stack([mask_bin] * 4, axis=-1).astype(np.float32)
    defecto_arr = np.array(defecto_img).astype(np.float32)
    defecto_recortado = defecto_arr * mask_rgba
    alpha = create_soft_mask(defecto_recortado)
    alpha = np.stack([alpha] * 4, axis=-1)
    alpha *= mask_rgba
    sano_arr = np.array(sano_img).astype(np.float32)
    combinado = sano_arr * (1 - alpha) + defecto_recortado * alpha
    return Image.fromarray(np.clip(combinado, 0, 255).astype(np.uint8))

# ---------------------------
# 4. PROCESAR: CADA AGUACATE SANO + DEFECTO ALEATORIO
# ---------------------------
sano_imgs = sorted([f for f in os.listdir(dir_sanos) if f.lower().endswith(('.png', '.jpg'))])
defecto_imgs = sorted([f for f in os.listdir(dir_defectos) if f.lower().endswith(('.png', '.jpg'))])

contador = 0
for s_idx, sano_file in enumerate(sano_imgs):
    sano_path = os.path.join(dir_sanos, sano_file)
    sano_img = Image.open(sano_path)

    defecto_file = random.choice(defecto_imgs)
    defecto_path = os.path.join(dir_defectos, defecto_file)
    defecto_img = Image.open(defecto_path)

    combinado = aplicar_defecto_con_mascara_verde(sano_img, defecto_img)

    nombre_resultado = f"random_def_sano{s_idx+1:03}.png"
    combinado.save(os.path.join(dir_resultados, nombre_resultado))

    # Gráfico comparativo
    fig, axs = plt.subplots(1, 3, figsize=(9, 3))
    axs[0].imshow(sano_img.resize((128, 128)))
    axs[0].set_title("Sano")
    axs[1].imshow(defecto_img.resize((128, 128)))
    axs[1].set_title("Defecto")
    axs[2].imshow(combinado)
    axs[2].set_title("Combinado")
    for ax in axs:
        ax.axis("off")
    plt.tight_layout()
    plt.savefig(os.path.join(graficos_dir, f"grafico_sano{s_idx+1:03}.png"))
    plt.close()

    contador += 1

print(f"✅ {contador} combinaciones generadas con defectos aleatorios.")
print(f"Guardadas en: {dir_resultados} y {graficos_dir}")
# Out:
# ✅ 1764 combinaciones generadas con defectos aleatorios.
# Guardadas en: sanos_con_defectos y graficos_comparacion
